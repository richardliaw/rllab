# %%
import matplotlib
matplotlib.use('MacOSX')
import matplotlib.pyplot as plt
import numpy as np
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Parameters:
# ```
# algo = TRPO(
#     env=env,
#     policy=policy,
#     baseline=baseline,
#     batch_size=1000,
#     max_path_length=500,
#     n_itr=40,
#     discount=0.99,
#     step_size=0.01,
# )
#
# run_experiment_lite(
#     algo.train(),
#     # Number of parallel workers for sampling
#     n_parallel=4, (and 1)
# }
# ```

# %%
# Loading trajectory lengths of experiment with 4 workers
import pickle
with open("rllab/worker_4_tlengths.pkl") as f:
    data_4 = pickle.load(f)

# %%
% matplotlib inline
ITR = 5
plt.hist(data_4[5:25:4], 5, normed=True)
plt.show()

# %%
plt.title("Cartpole for 4 workers")
plt.axis("on")
plt.ylabel("Cumulative distribution of trajectory lengths")
plt.hist(data_4[:5], 50, normed=True, histtype='step', cumulative=True)
plt.show()

# %%
import pickle
with open("rllab/worker_1_tlengths.pkl") as f:
    data_1 = pickle.load(f)

# %%
plt.hist(data_1[5:25:4], 5, normed=True)
plt.show()

# %%
plt.hist(data_1[:5], 50, normed=True, histtype='step', cumulative=True)
plt.show()

# %%
plt.hist([data_4[1], data_1[1]], normed=True)
plt.show()

# %%
ITR = 8
plt.hist([data_4[ITR],data_4_20[ITR], data_1[ITR], data_1_20[ITR]], normed=True, color=['r', 'r', 'b', 'b'])
plt.show()

# %% [markdown]
# Clearly, by 8 iterations, outliers are mainly the 4-worker implementation...

# %% [markdown]
# # Verification:
#
# Seed = 20

# %%
import pickle
with open("rllab/2016-10-29_15-33-22_worker_4_tlengths.pkl") as f:
    data_4_20 = pickle.load(f)
plt.hist(data_4_20[5:25:2], 50, normed=True, histtype='step', cumulative=True)
plt.show()

# %%
with open("rllab/2016-10-29_15-38-06_worker_1_tlengths.pkl") as f:
    data_1_20 = pickle.load(f)
plt.hist(data_1_20[5:25:2], 50, normed=True, histtype='step', cumulative=True)
plt.show()

# %%
import plotly.tools as tls
tls.embed("https://plot.ly/~richardliaw/56/")
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~richardliaw/56.embed" height="525" width="100%"></iframe>

# %%
tls.embed("https://plot.ly/~richardliaw/58/")
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~richardliaw/58.embed" height="525" width="100%"></iframe>

# %%
tls.embed("https://plot.ly/~richardliaw/60/")
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~richardliaw/60.embed" height="525" width="100%"></iframe>
